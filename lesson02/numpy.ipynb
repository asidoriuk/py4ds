# %%
import numpy as np

# %%
A = np.array([[1, 6], [2, 8], [3, 11], [3, 10], [1, 7]])
A
# Out:
# array([[ 1,  6],
#        [ 2,  8],
#        [ 3, 11],
#        [ 3, 10],
#        [ 1,  7]])

# %%
mean_a = A.mean(axis = 0)
mean_a
# Out:
# array([2. , 8.4])

# %%
a_centered = A - mean_a
a_centered
# Out:
# array([[-1. , -2.4],
#        [ 0. , -0.4],
#        [ 1. ,  2.6],
#        [ 1. ,  1.6],
#        [-1. , -1.4]])

# %%
a_centered_sp = a_centered[:,0] @ a_centered[:,1]
print(a_centered_sp)
a_centered_sp / (5 - 1)
# Out:
# 8.0
# 2.0

# %%
a_cov = np.cov(A.T)
a_cov
# Out:
# array([[1. , 2. ],
#        [2. , 4.3]])

# %%
a_cov[0, 1]
# Out:
# 2.0
